# %%
from __future__ import print_function
import torch

# %%
x = torch.rand(5,3)
x
# Out:
# tensor([[0.8810, 0.9404, 0.2031],
#         [0.4972, 0.5745, 0.9313],
#         [0.2276, 0.1859, 0.1859],
#         [0.7491, 0.6383, 0.9479],
#         [0.6531, 0.7747, 0.8572]])

# %%
import numpy as np
d= 30000

A = torch.rand(d,d).cuda()
B = torch.rand(d,d).cuda()
print(torch.cuda.get_device_name(0))

C= torch.mm(A,B)

C
# Out:
# Tesla K80
# tensor([[7515.7607, 7538.1260, 7545.9189,  ..., 7526.2510, 7551.5439,
#          7554.2295],
#         [7452.7944, 7460.7803, 7464.2236,  ..., 7484.4888, 7491.4204,
#          7483.1831],
#         [7456.2324, 7472.7002, 7519.6050,  ..., 7501.3623, 7506.3159,
#          7518.0610],
#         ...,
#         [7454.8018, 7470.5708, 7488.7539,  ..., 7521.4229, 7522.8105,
#          7514.4849],
#         [7506.6597, 7509.9961, 7540.2368,  ..., 7553.8828, 7564.2363,
#          7552.9380],
#         [7414.7495, 7424.3979, 7476.4995,  ..., 7477.8784, 7482.1895,
#          7462.8066]], device='cuda:0')
